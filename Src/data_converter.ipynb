# %%
import pandas as pd
import numpy as np
import os

# %%
data_path = r"C:/Users/hetpa/OneDrive/Desktop/AIML/AI Agent Sales/Data/raw/Year 2009-2010.csv"

# Load dataset with encoding fix
df = pd.read_csv(data_path, encoding='ISO-8859-1')

print(f"Loaded dataset with {len(df)} records.")
df.head()
# Out:
# Loaded dataset with 525461 records.
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country
# 0  12/1/2009 7:45   6.95      13085.0  United Kingdom
# 1  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 2  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 3  12/1/2009 7:45   2.10      13085.0  United Kingdom
# 4  12/1/2009 7:45   1.25      13085.0  United Kingdom

# %%
# Remove invalid entries
df = df.dropna(subset=['Customer ID', 'InvoiceDate', 'Quantity', 'Price'])
df = df[(df['Quantity'] > 0) & (df['Price'] > 0)]
df = df.reset_index(drop=True)
print(df.shape)
df.head()
# Out:
# (407664, 8)
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country
# 0  12/1/2009 7:45   6.95      13085.0  United Kingdom
# 1  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 2  12/1/2009 7:45   6.75      13085.0  United Kingdom
# 3  12/1/2009 7:45   2.10      13085.0  United Kingdom
# 4  12/1/2009 7:45   1.25      13085.0  United Kingdom

# %%
# --- Feature Mapping ---
df['Deal Amount'] = df['Quantity'] * df['Price']
df['Last Contact Date'] = pd.to_datetime(df['InvoiceDate'])
df['Industry'] = df['Country']

# --- Simulate fields not present ---
df['Sales Stage'] = np.random.choice(['Contacted', 'Negotiation', 'Proposal Sent'], size=len(df))
df['Lead Source'] = np.random.choice(['Website', 'Referral', 'Social Media', 'Event'], size=len(df))
df['Emails'] = np.random.randint(1, 10, size=len(df))
df['Meetings'] = np.random.randint(0, 5, size=len(df))
df['Deal Status'] = np.random.choice([0,1], size=len(df), p=[0.7, 0.3])  # 70% negative class

df.head()
# Out:
#   Invoice StockCode                          Description  Quantity  \
# 0  489434     85048  15CM CHRISTMAS GLASS BALL 20 LIGHTS        12
# 1  489434    79323P                   PINK CHERRY LIGHTS        12
# 2  489434    79323W                  WHITE CHERRY LIGHTS        12
# 3  489434     22041         RECORD FRAME 7" SINGLE SIZE         48
# 4  489434     21232       STRAWBERRY CERAMIC TRINKET BOX        24
#
#       InvoiceDate  Price  Customer ID         Country  Deal Amount  \
# 0  12/1/2009 7:45   6.95      13085.0  United Kingdom         83.4
# 1  12/1/2009 7:45   6.75      13085.0  United Kingdom         81.0
# 2  12/1/2009 7:45   6.75      13085.0  United Kingdom         81.0
# 3  12/1/2009 7:45   2.10      13085.0  United Kingdom        100.8
# 4  12/1/2009 7:45   1.25      13085.0  United Kingdom         30.0
#
#     Last Contact Date        Industry  Sales Stage   Lead Source  Emails  \
# 0 2009-12-01 07:45:00  United Kingdom    Contacted         Event       7
# 1 2009-12-01 07:45:00  United Kingdom    Contacted  Social Media       8
# 2 2009-12-01 07:45:00  United Kingdom    Contacted         Event       9
# 3 2009-12-01 07:45:00  United Kingdom  Negotiation  Social Media       9
# 4 2009-12-01 07:45:00  United Kingdom  Negotiation      Referral       9
#
#    Meetings  Deal Status
# 0         4            0
# 1         4            0
# 2         2            0
# 3         2            0
# 4         3            1

# %%
crm_df = df[['Industry', 'Sales Stage', 'Lead Source', 'Deal Amount', 
             'Last Contact Date', 'Emails', 'Meetings', 'Deal Status']]

print("Final shape:", crm_df.shape)
crm_df.head()
# Out:
# Final shape: (407664, 8)
#          Industry  Sales Stage   Lead Source  Deal Amount   Last Contact Date  \
# 0  United Kingdom    Contacted         Event         83.4 2009-12-01 07:45:00
# 1  United Kingdom    Contacted  Social Media         81.0 2009-12-01 07:45:00
# 2  United Kingdom    Contacted         Event         81.0 2009-12-01 07:45:00
# 3  United Kingdom  Negotiation  Social Media        100.8 2009-12-01 07:45:00
# 4  United Kingdom  Negotiation      Referral         30.0 2009-12-01 07:45:00
#
#    Emails  Meetings  Deal Status
# 0       7         4            0
# 1       8         4            0
# 2       9         2            0
# 3       9         2            0
# 4       9         3            1

# %%
# Make sure processed folder exists
os.makedirs(r"C:/Users/hetpa/OneDrive/Desktop/AIML/AI Agent Sales/Data/processes data", exist_ok=True)

# Save as CSV
crm_df.to_csv("C:/Users/hetpa/OneDrive/Desktop/AIML/AI Agent Sales/Data/processes data/converted_sales_data.csv", index=False)

print("✅ Converted dataset saved successfully")
# Out:
# ✅ Converted dataset saved successfully
